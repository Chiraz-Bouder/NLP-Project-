# %%
import os
import re
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Uploading the data

# %%
data = []
labels = []



dataset_path = "movies1000"

for label in ["pos", "neg"]:
    folder = os.path.join(dataset_path, label)

    for file in os.listdir(folder):
        with open(os.path.join(folder, file), encoding="utf8") as f:
            text = f.read()
            data.append(text)

            if label == "pos":
                labels.append(1)
            else:
                labels.append(0)

# %% [markdown]
# ## preprocessing

# %%
def preprocess(text) : 
    text = text.lower()
    text = re.sub('(www|http)[\w\.-_]+\.(fr|com|org)', 'URL', text)
    text = re.sub('[0-9]+', '', text)
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text)
    return text 

data = [preprocess(t) for t in data]

# %% [markdown]
# ## convert text to numerical features

# %%
vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words="english",
    ngram_range=(1,2)
)

X = vectorizer.fit_transform(data)

# %% [markdown]
# ## training

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, labels, test_size=0.2, random_state=42
)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## Evaluation

# %%
pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.8025

# %%
pred_labels = ["P" if p == 1 else "N" for p in pred]

# %% [markdown]
# ## TEST

# %%
test_data = []
with open("movies1000/test/testSentiment.txt", encoding="utf8") as f:
    for line in f:
        test_data.append(line.strip())

test = vectorizer.transform(test_data)

pred2 = model.predict(test)

pred_labels2 = ["P" if p == 1 else "N" for p in pred2]

# %%
import pandas as pd

pd.DataFrame(pred_labels).to_csv("SentimentDetection.csv", index=False, header=False)
